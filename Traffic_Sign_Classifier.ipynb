# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Deep Learning
#
# ## Project: Build a Traffic Sign Recognition Classifier
#
# In this notebook, a template is provided for you to implement your functionality in stages, which is required to successfully complete this project. If additional code is required that cannot be included in the notebook, be sure that the Python code is successfully imported and included in your submission if necessary.
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there is a writeup to complete. The writeup should be completed in a separate file, which can be either a markdown file or a pdf document. There is a [write up template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) that can be used to guide the writing process. Completing the code template and writeup template will cover all of the [rubric points](https://review.udacity.com/#!/rubrics/481/view) for this project.
#
# The [rubric](https://review.udacity.com/#!/rubrics/481/view) contains "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. The stand out suggestions are optional. If you decide to pursue the "stand out suggestions", you can include the code in this Ipython notebook and also discuss the results in the writeup file.
#
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Flatten
from keras import optimizers,layers
import random

# %% [markdown]
# ---
# ## Step 0: Load The Data

# %%
# TODO: Fill this in based on where you saved the training and testing data

training_file = 'traffic-signs-data/train.p'
validation_file= 'traffic-signs-data/valid.p'
testing_file = 'traffic-signs-data/test.p'

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %% [markdown]
# ---
#
# ## Step 1: Dataset Summary & Exploration
#
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 1D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**
#
# Complete the basic data summary below. Use python, numpy and/or pandas methods to calculate the data summary rather than hard coding the results. For example, the [pandas shape method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.shape.html) might be useful for calculating some of the summary results.

# %% [markdown]
# ### Provide a Basic Summary of the Data Set Using Python, Numpy and/or Pandas

# %%
### Replace each question mark with the appropriate value. 
### Use python, pandas or numpy methods rather than hard coding the results

# TODO: Number of training examples
n_train = X_train.shape[0]

# TODO: Number of validation examples
n_validation = X_valid.shape[0]

# TODO: Number of testing examples.
n_test = X_test.shape[0]

# TODO: What's the shape of a traffic sign image?
image_shape = X_train[0].shape

# TODO: How many unique classes/labels there are in the dataset.
n_classes = len(np.unique(y_train))

print("Number of training examples =", n_train)
print("Number of testing examples =", n_test)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Number of training examples = 34799
# Number of testing examples = 12630
# Image data shape = (32, 32, 3)
# Number of classes = 43

# %% [markdown]
# ### Include an exploratory visualization of the dataset

# %% [markdown]
# Visualize the German Traffic Signs Dataset using the pickled file(s). This is open ended, suggestions include: plotting traffic sign images, plotting the count of each sign, etc.
#
# The [Matplotlib](http://matplotlib.org/) [examples](http://matplotlib.org/examples/index.html) and [gallery](http://matplotlib.org/gallery.html) pages are a great resource for doing visualizations in Python.
#
# **NOTE:** It's recommended you start with something simple first. If you wish to do more, come back to it after you've completed the rest of the sections. It can be interesting to look at the distribution of classes in the training, validation and test set. Is the distribution the same? Are there more examples of some classes than others?

# %%
# Load the sign names mapping
signnames = pd.read_csv('signnames.csv')

# Extract the features and labels
features = train['features']
labels = train['labels']

# Count the occurrences of each sign class
class_counts = np.bincount(labels)

# Visualize a random sample of traffic sign images
plt.figure(figsize=(12, 12))
for i in range(16):  # Change the number of samples as needed
    plt.subplot(4, 4, i + 1)
    index = random.randint(0, len(features) - 1)
    image = features[index]
    label = labels[index]
    plt.title(signnames['SignName'][label])
    plt.imshow(image)
    plt.axis('off')

# Visualize the distribution of sign classes
plt.figure(figsize=(12, 6))
plt.bar(range(len(class_counts)), class_counts, tick_label=signnames['SignName'], align='center')
plt.xticks(rotation=90)
plt.xlabel('Traffic Sign Class')
plt.ylabel('Number of Samples')
plt.title('Distribution of Traffic Sign Classes')

plt.tight_layout()
plt.show()

# %% [markdown]
# ----
#
# ## Step 2: Design and Test a Model Architecture
#
# Design and implement a deep learning model that learns to recognize traffic signs. Train and test your model on the [German Traffic Sign Dataset](http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset).
#
# The LeNet-5 implementation shown in the [classroom](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) at the end of the CNN lesson is a solid starting point. You'll have to change the number of classes and possibly the preprocessing, but aside from that it's plug and play!
#
# With the LeNet-5 solution from the lecture, you should expect a validation set accuracy of about 0.89. To meet specifications, the validation set accuracy will need to be at least 0.93. It is possible to get an even higher accuracy, but 0.93 is the minimum for a successful project submission.
#
# There are various aspects to consider when thinking about this problem:
#
# - Neural network architecture (is the network over or underfitting?)
# - Play around preprocessing techniques (normalization, rgb to grayscale, etc)
# - Number of examples per label (some have more than others).
# - Generate fake data.
#
# Here is an example of a [published baseline model on this problem](http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf). It's not required to be familiar with the approach used in the paper but, it's good practice to try to read papers like these.

# %% [markdown]
# ### Pre-process the Data Set (normalization, grayscale, etc.)

# %% [markdown]
# Minimally, the image data should be normalized so that the data has mean zero and equal variance. For image data, `(pixel - 128)/ 128` is a quick way to approximately normalize the data and can be used in this project.
#
# Other pre-processing steps are optional. You can try different techniques to see if it improves performance.
#
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project.

# %%
### Preprocess the data here. It is required to normalize the data. Other preprocessing steps could include 
# Normalize the data
X_train = (X_train - 128) / 128
X_valid = (X_valid - 128) / 128
X_test = (X_test - 128) / 128

### converting to grayscale, etc.

### Feel free to use as many code cells as needed.

# %% [markdown]
# ### Model Architecture

# %%
### Define your architecture here.
### Feel free to use as many code cells as needed.

# Define the LeNet-5 model architecture (or adapt it as needed)
model = Sequential([
    # Layer 1: Convolutional Layer
    layers.Conv2D(16, (5, 5), activation='relu', input_shape=(32, 32, 3)),
    layers.MaxPooling2D(pool_size=(2, 2)),
    
    # Layer 2: Convolutional Layer
    layers.Conv2D(64, (5, 5), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    
    # Flatten the output for the fully connected layers
    layers.Flatten(),
    
    # Layer 3: Fully Connected Layer
    layers.Dense(120, activation='relu'),
    
    # Layer 3: Fully Connected Layer
    layers.Dense(160, activation='relu'),
    
    # Layer 4: Fully Connected Layer
    layers.Dense(84, activation='relu'),
    
    # Layer 5: Output Layer
    layers.Dense(43, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 16)        1216
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 10, 10, 64)        25664
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 120)               192120
#
#  dense_1 (Dense)             (None, 160)               19360
#
#  dense_2 (Dense)             (None, 84)                13524
#
#  dense_3 (Dense)             (None, 43)                3655
#
# =================================================================
# Total params: 255,539
# Trainable params: 255,539
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train, Validate and Test the Model

# %% [markdown]
# A validation set can be used to assess how well the model is performing. A low accuracy on the training and validation
# sets imply underfitting. A high accuracy on the training set but low accuracy on the validation set implies overfitting.

# %%
### Train your model here.
# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=10, validation_data=(X_valid, y_valid), batch_size=128)

# Evaluate the model on the test dataset
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test accuracy: {test_accuracy}")
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.
# Out:
# Epoch 1/10
# 2023-09-06 13:29:24.855927: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 272/272 [==============================] - 7s 24ms/step - loss: 2.5103 - accuracy: 0.3087 - val_loss: 2.0330 - val_accuracy: 0.4322
# Epoch 2/10
# 272/272 [==============================] - 7s 24ms/step - loss: 0.9007 - accuracy: 0.7219 - val_loss: 1.1863 - val_accuracy: 0.6773
# Epoch 3/10
# 272/272 [==============================] - 7s 25ms/step - loss: 0.4131 - accuracy: 0.8756 - val_loss: 1.2112 - val_accuracy: 0.7200
# Epoch 4/10
# 272/272 [==============================] - 7s 24ms/step - loss: 0.2436 - accuracy: 0.9257 - val_loss: 1.0994 - val_accuracy: 0.7510
# Epoch 5/10
# 272/272 [==============================] - 7s 24ms/step - loss: 0.1517 - accuracy: 0.9546 - val_loss: 1.1090 - val_accuracy: 0.7757
# Epoch 6/10
# 272/272 [==============================] - 7s 24ms/step - loss: 0.1081 - accuracy: 0.9682 - val_loss: 1.2637 - val_accuracy: 0.7766
# Epoch 7/10
# 272/272 [==============================] - 7s 24ms/step - loss: 0.0863 - accuracy: 0.9750 - val_loss: 1.4179 - val_accuracy: 0.7562
# Epoch 8/10
# 272/272 [==============================] - 7s 25ms/step - loss: 0.0746 - accuracy: 0.9772 - val_loss: 1.2615 - val_accuracy: 0.7816
# Epoch 9/10
# 272/272 [==============================] - 7s 25ms/step - loss: 0.0547 - accuracy: 0.9826 - val_loss: 1.2069 - val_accuracy: 0.7927
# Epoch 10/10
# 272/272 [==============================] - 7s 25ms/step - loss: 0.0627 - accuracy: 0.9811 - val_loss: 1.3733 - val_accuracy: 0.7837
# 395/395 [==============================] - 1s 4ms/step - loss: 1.1747 - accuracy: 0.7958
# Test accuracy: 0.7958036661148071

# %% [markdown]
# ---
#
# ## Step 3: Test a Model on New Images
#
# To give yourself more insight into how your model is working, download at least five pictures of German traffic signs from the web and use your model to predict the traffic sign type.
#
# You may find `signnames.csv` useful as it contains mappings from the class id (integer) to the actual sign name.

# %% [markdown]
# ### Load and Output the Images

# %%
### Load the images and plot them here.
### Feel free to use as many code cells as needed.
# Load the class names (signnames.csv)
class_names = {}
with open('signnames.csv', 'r') as file:
    for line in file.readlines()[1:]:
        class_id, class_name = line.strip().split(',')
        class_names[int(class_id)] = class_name

# Load and preprocess the new images
new_images = []
new_image_paths = X_test  # Replace with your image file paths
for image in new_image_paths:
    img = (image - 128) / 128  # Normalize
    new_images.append(img)

new_images = np.array(new_images)

# Make predictions
predictions = model.predict(new_images)

# # Interpret the results
# for i, prediction in enumerate(predictions):
#     predicted_class_id = np.argmax(prediction)
#     predicted_class_name = class_names[predicted_class_id]
    
#     plt.imshow(new_image_paths[i])
#     plt.title(f"Predicted: {predicted_class_name}")
#     plt.show()
predictions
# Out:
# 395/395 [==============================] - 1s 3ms/step
# array([[0.00046547, 0.0081449 , 0.00233157, ..., 0.02074699, 0.00165273,
#         0.00026279],
#        [0.000481  , 0.0080385 , 0.00226801, ..., 0.02059854, 0.00169015,
#         0.00027182],
#        [0.00046056, 0.00801055, 0.00217256, ..., 0.01975407, 0.00152705,
#         0.00024942],
#        ...,
#        [0.00046814, 0.00785084, 0.00236087, ..., 0.0201705 , 0.00168909,
#         0.00026971],
#        [0.00046958, 0.00783515, 0.00234103, ..., 0.02030998, 0.00166952,
#         0.00026544],
#        [0.00046069, 0.00771934, 0.00232311, ..., 0.02030759, 0.00170068,
#         0.00026804]], dtype=float32)

# %% [markdown]
# ### Analyze performance

# %%
### Calculate the accuracy for these 5 new images. 
### For example, if the model predicted 1 out of 5 signs correctly, it's 20% accurate on these new images.
correct_predictions = 0
total_predictions = len(new_images)

for i, prediction in enumerate(predictions):
    predicted_class_id = np.argmax(prediction)
    actual_class_id = y_test[i]  # You need to know the actual class IDs of the new images
    
    if predicted_class_id == actual_class_id:
        correct_predictions += 1

accuracy = correct_predictions / total_predictions
print(f"Accuracy on new images: {accuracy * 100:.2f}%")


from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

actual_class_ids = y_test  # List of actual class IDs for the new images
predicted_class_ids = [np.argmax(prediction) for prediction in predictions]

cm = confusion_matrix(actual_class_ids, predicted_class_ids)
ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names.values()).plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()
# Out:
# Accuracy on new images: 3.09%

# %% [markdown]
# ### Output Top 5 Softmax Probabilities For Each Image Found on the Web

# %% [markdown]
# For each of the new images, print out the model's softmax probabilities to show the **certainty** of the model's predictions (limit the output to the top 5 probabilities for each image). [`tf.nn.top_k`](https://www.tensorflow.org/versions/r0.12/api_docs/python/nn.html#top_k) could prove helpful here.
#
# The example below demonstrates how tf.nn.top_k can be used to find the top k predictions for each image.
#
# `tf.nn.top_k` will return the values and indices (class ids) of the top k predictions. So if k=3, for each sign, it'll return the 3 largest probabilities (out of a possible 43) and the correspoding class ids.
#
# Take this numpy array as an example. The values in the array represent predictions. The array contains softmax probabilities for five candidate images with six possible classes. `tf.nn.top_k` is used to choose the three classes with the highest probability:
#
# ```
# # (5, 6) array
# a = np.array([[ 0.24879643,  0.07032244,  0.12641572,  0.34763842,  0.07893497,
#          0.12789202],
#        [ 0.28086119,  0.27569815,  0.08594638,  0.0178669 ,  0.18063401,
#          0.15899337],
#        [ 0.26076848,  0.23664738,  0.08020603,  0.07001922,  0.1134371 ,
#          0.23892179],
#        [ 0.11943333,  0.29198961,  0.02605103,  0.26234032,  0.1351348 ,
#          0.16505091],
#        [ 0.09561176,  0.34396535,  0.0643941 ,  0.16240774,  0.24206137,
#          0.09155967]])
# ```
#
# Running it through `sess.run(tf.nn.top_k(tf.constant(a), k=3))` produces:
#
# ```
# TopKV2(values=array([[ 0.34763842,  0.24879643,  0.12789202],
#        [ 0.28086119,  0.27569815,  0.18063401],
#        [ 0.26076848,  0.23892179,  0.23664738],
#        [ 0.29198961,  0.26234032,  0.16505091],
#        [ 0.34396535,  0.24206137,  0.16240774]]), indices=array([[3, 0, 5],
#        [0, 1, 4],
#        [0, 5, 1],
#        [1, 3, 5],
#        [1, 4, 3]], dtype=int32))
# ```
#
# Looking just at the first row we get `[ 0.34763842,  0.24879643,  0.12789202]`, you can confirm these are the 3 largest probabilities in `a`. You'll also notice `[3, 0, 5]` are the corresponding indices.

# %%
### Print out the top five softmax probabilities for the predictions on the German traffic sign images found on the web. 
### Feel free to use as many code cells as needed.
import numpy as np

# Assuming 'model' is your trained Keras model and 'new_images' contains your preprocessed images

# Step 1: Predict class probabilities for the new images
class_probabilities = model.predict(new_images)

# Step 2: Find and print the top 5 probabilities and class indices
top_k = np.argsort(class_probabilities, axis=1)[:, -5:]  # Get the indices of the top 5 probabilities

for i, top_classes in enumerate(top_k):
    print(f"Top 5 softmax probabilities for Image {i + 1}:")
    for class_idx in top_classes:
        probability = class_probabilities[i][class_idx]
        sign_name = class_names[class_idx]  # Assuming you have a dictionary mapping class IDs to sign names
        print(f"  Sign: {sign_name} (Class {class_idx}), Probability: {probability:.4f}")
# Out:
# 395/395 [==============================] - 1s 3ms/step
# Top 5 softmax probabilities for Image 1:
#   Sign: Go straight or left (Class 37), Probability: 0.0337
#   Sign: Go straight or right (Class 36), Probability: 0.0339
#   Sign: Keep right (Class 38), Probability: 0.0403
#   Sign: Keep left (Class 39), Probability: 0.0610
#   Sign: Ahead only (Class 35), Probability: 0.6661
# Top 5 softmax probabilities for Image 2:
#   Sign: Go straight or left (Class 37), Probability: 0.0345
#   Sign: Go straight or right (Class 36), Probability: 0.0352
#   Sign: Keep right (Class 38), Probability: 0.0408
#   Sign: Keep left (Class 39), Probability: 0.0602
#   Sign: Ahead only (Class 35), Probability: 0.6615
# Top 5 softmax probabilities for Image 3:
#   Sign: Go straight or right (Class 36), Probability: 0.0345
#   Sign: Go straight or left (Class 37), Probability: 0.0349
#   Sign: Keep right (Class 38), Probability: 0.0412
#   Sign: Keep left (Class 39), Probability: 0.0616
#   Sign: Ahead only (Class 35), Probability: 0.6637
# Top 5 softmax probabilities for Image 4:
#   Sign: Go straight or left (Class 37), Probability: 0.0354
#   Sign: Go straight or right (Class 36), Probability: 0.0370
#   Sign: Keep right (Class 38), Probability: 0.0410
#   Sign: Keep left (Class 39), Probability: 0.0617
#   Sign: Ahead only (Class 35), Probability: 0.6632
# Top 5 softmax probabilities for Image 5:
#   Sign: Go straight or right (Class 36), Probability: 0.0341
#   Sign: Go straight or left (Class 37), Probability: 0.0350
#   Sign: Keep right (Class 38), Probability: 0.0394
#   Sign: Keep left (Class 39), Probability: 0.0614
#   Sign: Ahead only (Class 35), Probability: 0.6635
# Top 5 softmax probabilities for Image 6:
#   Sign: Go straight or right (Class 36), Probability: 0.0344
#   Sign: Go straight or left (Class 37), Probability: 0.0347
#   Sign: Keep right (Class 38), Probability: 0.0412
#   Sign: Keep left (Class 39), Probability: 0.0610
#   Sign: Ahead only (Class 35), Probability: 0.6652
# Top 5 softmax probabilities for Image 7:
#   Sign: Go straight or left (Class 37), Probability: 0.0340
#   Sign: Go straight or right (Class 36), Probability: 0.0340
#   Sign: Keep right (Class 38), Probability: 0.0376
#   Sign: Keep left (Class 39), Probability: 0.0591
#   Sign: Ahead only (Class 35), Probability: 0.6767
# Top 5 softmax probabilities for Image 8:
#   Sign: Go straight or left (Class 37), Probability: 0.0339
#   Sign: Go straight or right (Class 36), Probability: 0.0375
#   Sign: Keep right (Class 38), Probability: 0.0410
#   Sign: Keep left (Class 39), Probability: 0.0558
#   Sign: Ahead only (Class 35), Probability: 0.6637
# Top 5 softmax probabilities for Image 9:
#   Sign: Go straight or right (Class 36), Probability: 0.0333
#   Sign: Go straight or left (Class 37), Probability: 0.0350
#   Sign: Keep right (Class 38), Probability: 0.0380
#   Sign: Keep left (Class 39), Probability: 0.0609
#   Sign: Ahead only (Class 35), Probability: 0.6717
# Top 5 softmax probabilities for Image 10:
#   Sign: Go straight or left (Class 37), Probability: 0.0334
#   Sign: Go straight or right (Class 36), Probability: 0.0358
#   Sign: Keep right (Class 38), Probability: 0.0384
#   Sign: Keep left (Class 39), Probability: 0.0544
#   Sign: Ahead only (Class 35), Probability: 0.6756
# Top 5 softmax probabilities for Image 11:
#   Sign: Go straight or right (Class 36), Probability: 0.0331
#   Sign: Go straight or left (Class 37), Probability: 0.0341
#   Sign: Keep right (Class 38), Probability: 0.0387
#   Sign: Keep left (Class 39), Probability: 0.0602
#   Sign: Ahead only (Class 35), Probability: 0.6723
# Top 5 softmax probabilities for Image 12:
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Go straight or right (Class 36), Probability: 0.0357
#   Sign: Keep right (Class 38), Probability: 0.0399
#   Sign: Keep left (Class 39), Probability: 0.0607
#   Sign: Ahead only (Class 35), Probability: 0.6638
# Top 5 softmax probabilities for Image 13:
#   Sign: Go straight or right (Class 36), Probability: 0.0333
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0385
#   Sign: Keep left (Class 39), Probability: 0.0604
#   Sign: Ahead only (Class 35), Probability: 0.6678
# Top 5 softmax probabilities for Image 14:
#   Sign: Go straight or right (Class 36), Probability: 0.0323
#   Sign: Go straight or left (Class 37), Probability: 0.0339
#   Sign: Keep right (Class 38), Probability: 0.0378
#   Sign: Keep left (Class 39), Probability: 0.0602
#   Sign: Ahead only (Class 35), Probability: 0.6743
# Top 5 softmax probabilities for Image 15:
#   Sign: Go straight or left (Class 37), Probability: 0.0347
#   Sign: Go straight or right (Class 36), Probability: 0.0355
#   Sign: Keep right (Class 38), Probability: 0.0403
#   Sign: Keep left (Class 39), Probability: 0.0636
#   Sign: Ahead only (Class 35), Probability: 0.6569
# Top 5 softmax probabilities for Image 16:
#   Sign: Go straight or left (Class 37), Probability: 0.0345
#   Sign: Go straight or right (Class 36), Probability: 0.0357
#   Sign: Keep right (Class 38), Probability: 0.0401
#   Sign: Keep left (Class 39), Probability: 0.0596
#   Sign: Ahead only (Class 35), Probability: 0.6611
# Top 5 softmax probabilities for Image 17:
#   Sign: Go straight or right (Class 36), Probability: 0.0328
#   Sign: Go straight or left (Class 37), Probability: 0.0341
#   Sign: Keep right (Class 38), Probability: 0.0387
#   Sign: Keep left (Class 39), Probability: 0.0600
#   Sign: Ahead only (Class 35), Probability: 0.6688
# Top 5 softmax probabilities for Image 18:
#   Sign: Go straight or left (Class 37), Probability: 0.0337
#   Sign: Go straight or right (Class 36), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0389
#   Sign: Keep left (Class 39), Probability: 0.0594
#   Sign: Ahead only (Class 35), Probability: 0.6704
# Top 5 softmax probabilities for Image 19:
#   Sign: Go straight or left (Class 37), Probability: 0.0341
#   Sign: Go straight or right (Class 36), Probability: 0.0355
#   Sign: Keep right (Class 38), Probability: 0.0399
#   Sign: Keep left (Class 39), Probability: 0.0594
#   Sign: Ahead only (Class 35), Probability: 0.6656
# Top 5 softmax probabilities for Image 20:
#   Sign: Go straight or left (Class 37), Probability: 0.0353
#   Sign: Go straight or right (Class 36), Probability: 0.0359
#   Sign: Keep right (Class 38), Probability: 0.0419
#   Sign: Keep left (Class 39), Probability: 0.0595
#   Sign: Ahead only (Class 35), Probability: 0.6593
# Top 5 softmax probabilities for Image 21:
#   Sign: Go straight or right (Class 36), Probability: 0.0332
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0386
#   Sign: Keep left (Class 39), Probability: 0.0605
#   Sign: Ahead only (Class 35), Probability: 0.6685
# Top 5 softmax probabilities for Image 22:
#   Sign: Go straight or left (Class 37), Probability: 0.0351
#   Sign: Go straight or right (Class 36), Probability: 0.0394
#   Sign: Keep right (Class 38), Probability: 0.0416
#   Sign: Keep left (Class 39), Probability: 0.0631
#   Sign: Ahead only (Class 35), Probability: 0.6477
# Top 5 softmax probabilities for Image 23:
#   Sign: Go straight or right (Class 36), Probability: 0.0334
#   Sign: Go straight or left (Class 37), Probability: 0.0348
#   Sign: Keep right (Class 38), Probability: 0.0387
#   Sign: Keep left (Class 39), Probability: 0.0605
#   Sign: Ahead only (Class 35), Probability: 0.6673
# Top 5 softmax probabilities for Image 24:
#   Sign: Go straight or right (Class 36), Probability: 0.0327
#   Sign: Go straight or left (Class 37), Probability: 0.0341
#   Sign: Keep right (Class 38), Probability: 0.0381
#   Sign: Keep left (Class 39), Probability: 0.0591
#   Sign: Ahead only (Class 35), Probability: 0.6735
# Top 5 softmax probabilities for Image 25:
#   Sign: Go straight or right (Class 36), Probability: 0.0333
#   Sign: Go straight or left (Class 37), Probability: 0.0345
#   Sign: Keep right (Class 38), Probability: 0.0400
#   Sign: Keep left (Class 39), Probability: 0.0614
#   Sign: Ahead only (Class 35), Probability: 0.6637
# Top 5 softmax probabilities for Image 26:
#   Sign: Go straight or right (Class 36), Probability: 0.0345
#   Sign: Go straight or left (Class 37), Probability: 0.0354
#   Sign: Keep right (Class 38), Probability: 0.0409
#   Sign: Keep left (Class 39), Probability: 0.0618
#   Sign: Ahead only (Class 35), Probability: 0.6599
# Top 5 softmax probabilities for Image 27:
#   Sign: Go straight or left (Class 37), Probability: 0.0354
#   Sign: Go straight or right (Class 36), Probability: 0.0369
#   Sign: Keep right (Class 38), Probability: 0.0422
#   Sign: Keep left (Class 39), Probability: 0.0654
#   Sign: Ahead only (Class 35), Probability: 0.6555
# Top 5 softmax probabilities for Image 28:
#   Sign: Go straight or right (Class 36), Probability: 0.0336
#   Sign: Go straight or left (Class 37), Probability: 0.0345
#   Sign: Keep right (Class 38), Probability: 0.0395
#   Sign: Keep left (Class 39), Probability: 0.0600
#   Sign: Ahead only (Class 35), Probability: 0.6659
# Top 5 softmax probabilities for Image 29:
#   Sign: Go straight or left (Class 37), Probability: 0.0330
#   Sign: Go straight or right (Class 36), Probability: 0.0356
#   Sign: Keep right (Class 38), Probability: 0.0383
#   Sign: Keep left (Class 39), Probability: 0.0585
#   Sign: Ahead only (Class 35), Probability: 0.6672
# Top 5 softmax probabilities for Image 30:
#   Sign: Go straight or left (Class 37), Probability: 0.0335
#   Sign: Go straight or right (Class 36), Probability: 0.0356
#   Sign: Keep right (Class 38), Probability: 0.0391
#   Sign: Keep left (Class 39), Probability: 0.0606
#   Sign: Ahead only (Class 35), Probability: 0.6639
# Top 5 softmax probabilities for Image 31:
#   Sign: Go straight or left (Class 37), Probability: 0.0353
#   Sign: Go straight or right (Class 36), Probability: 0.0364
#   Sign: Keep right (Class 38), Probability: 0.0411
#   Sign: Keep left (Class 39), Probability: 0.0608
#   Sign: Ahead only (Class 35), Probability: 0.6551
# Top 5 softmax probabilities for Image 32:
#   Sign: Go straight or left (Class 37), Probability: 0.0371
#   Sign: Go straight or right (Class 36), Probability: 0.0374
#   Sign: Keep right (Class 38), Probability: 0.0415
#   Sign: Keep left (Class 39), Probability: 0.0577
#   Sign: Ahead only (Class 35), Probability: 0.6472
# Top 5 softmax probabilities for Image 33:
#   Sign: Go straight or left (Class 37), Probability: 0.0352
#   Sign: Go straight or right (Class 36), Probability: 0.0371
#   Sign: Keep right (Class 38), Probability: 0.0393
#   Sign: Keep left (Class 39), Probability: 0.0637
#   Sign: Ahead only (Class 35), Probability: 0.6545
# Top 5 softmax probabilities for Image 34:
#   Sign: Go straight or right (Class 36), Probability: 0.0332
#   Sign: Go straight or left (Class 37), Probability: 0.0347
#   Sign: Keep right (Class 38), Probability: 0.0385
#   Sign: Keep left (Class 39), Probability: 0.0604
#   Sign: Ahead only (Class 35), Probability: 0.6679
# Top 5 softmax probabilities for Image 35:
#   Sign: Go straight or right (Class 36), Probability: 0.0356
#   Sign: Go straight or left (Class 37), Probability: 0.0357
#   Sign: Keep right (Class 38), Probability: 0.0406
#   Sign: Keep left (Class 39), Probability: 0.0634
#   Sign: Ahead only (Class 35), Probability: 0.6561
# Top 5 softmax probabilities for Image 36:
#   Sign: Go straight or right (Class 36), Probability: 0.0346
#   Sign: Go straight or left (Class 37), Probability: 0.0351
#   Sign: Keep right (Class 38), Probability: 0.0390
#   Sign: Keep left (Class 39), Probability: 0.0616
#   Sign: Ahead only (Class 35), Probability: 0.6618
# Top 5 softmax probabilities for Image 37:
#   Sign: Go straight or left (Class 37), Probability: 0.0352
#   Sign: Go straight or right (Class 36), Probability: 0.0361
#   Sign: Keep right (Class 38), Probability: 0.0413
#   Sign: Keep left (Class 39), Probability: 0.0622
#   Sign: Ahead only (Class 35), Probability: 0.6578
# Top 5 softmax probabilities for Image 38:
#   Sign: Go straight or right (Class 36), Probability: 0.0324
#   Sign: Go straight or left (Class 37), Probability: 0.0341
#   Sign: Keep right (Class 38), Probability: 0.0376
#   Sign: Keep left (Class 39), Probability: 0.0613
#   Sign: Ahead only (Class 35), Probability: 0.6733
# Top 5 softmax probabilities for Image 39:
#   Sign: Go straight or right (Class 36), Probability: 0.0329
#   Sign: Go straight or left (Class 37), Probability: 0.0336
#   Sign: Keep right (Class 38), Probability: 0.0388
#   Sign: Keep left (Class 39), Probability: 0.0624
#   Sign: Ahead only (Class 35), Probability: 0.6751
# Top 5 softmax probabilities for Image 40:
#   Sign: Go straight or right (Class 36), Probability: 0.0332
#   Sign: Go straight or left (Class 37), Probability: 0.0345
#   Sign: Keep right (Class 38), Probability: 0.0386
#   Sign: Keep left (Class 39), Probability: 0.0601
#   Sign: Ahead only (Class 35), Probability: 0.6684
# Top 5 softmax probabilities for Image 41:
#   Sign: Go straight or right (Class 36), Probability: 0.0332
#   Sign: Go straight or left (Class 37), Probability: 0.0345
#   Sign: Keep right (Class 38), Probability: 0.0388
#   Sign: Keep left (Class 39), Probability: 0.0602
#   Sign: Ahead only (Class 35), Probability: 0.6681
# Top 5 softmax probabilities for Image 42:
#   Sign: Go straight or right (Class 36), Probability: 0.0334
#   Sign: Go straight or left (Class 37), Probability: 0.0347
#   Sign: Keep right (Class 38), Probability: 0.0387
#   Sign: Keep left (Class 39), Probability: 0.0604
#   Sign: Ahead only (Class 35), Probability: 0.6670
# Top 5 softmax probabilities for Image 43:
#   Sign: Go straight or left (Class 37), Probability: 0.0353
#   Sign: Go straight or right (Class 36), Probability: 0.0357
#   Sign: Keep right (Class 38), Probability: 0.0403
#   Sign: Keep left (Class 39), Probability: 0.0595
#   Sign: Ahead only (Class 35), Probability: 0.6644
# Top 5 softmax probabilities for Image 44:
#   Sign: Go straight or right (Class 36), Probability: 0.0335
#   Sign: Go straight or left (Class 37), Probability: 0.0345
#   Sign: Keep right (Class 38), Probability: 0.0391
#   Sign: Keep left (Class 39), Probability: 0.0604
#   Sign: Ahead only (Class 35), Probability: 0.6667
# Top 5 softmax probabilities for Image 45:
#   Sign: Go straight or right (Class 36), Probability: 0.0345
#   Sign: Go straight or left (Class 37), Probability: 0.0352
#   Sign: Keep right (Class 38), Probability: 0.0397
#   Sign: Keep left (Class 39), Probability: 0.0617
#   Sign: Ahead only (Class 35), Probability: 0.6607
# Top 5 softmax probabilities for Image 46:
#   Sign: Go straight or left (Class 37), Probability: 0.0344
#   Sign: Go straight or right (Class 36), Probability: 0.0347
#   Sign: Keep right (Class 38), Probability: 0.0403
#   Sign: Keep left (Class 39), Probability: 0.0610
#   Sign: Ahead only (Class 35), Probability: 0.6618
# Top 5 softmax probabilities for Image 47:
#   Sign: Go straight or right (Class 36), Probability: 0.0342
#   Sign: Go straight or left (Class 37), Probability: 0.0348
#   Sign: Keep right (Class 38), Probability: 0.0402
#   Sign: Keep left (Class 39), Probability: 0.0608
#   Sign: Ahead only (Class 35), Probability: 0.6637
# Top 5 softmax probabilities for Image 48:
#   Sign: Go straight or right (Class 36), Probability: 0.0340
#   Sign: Go straight or left (Class 37), Probability: 0.0345
#   Sign: Keep right (Class 38), Probability: 0.0401
#   Sign: Keep left (Class 39), Probability: 0.0607
#   Sign: Ahead only (Class 35), Probability: 0.6647
# Top 5 softmax probabilities for Image 49:
#   Sign: Go straight or right (Class 36), Probability: 0.0332
#   Sign: Go straight or left (Class 37), Probability: 0.0345
#   Sign: Keep right (Class 38), Probability: 0.0381
#   Sign: Keep left (Class 39), Probability: 0.0596
#   Sign: Ahead only (Class 35), Probability: 0.6705
# Top 5 softmax probabilities for Image 50:
#   Sign: Go straight or right (Class 36), Probability: 0.0333
#   Sign: Go straight or left (Class 37), Probability: 0.0349
#   Sign: Keep right (Class 38), Probability: 0.0387
#   Sign: Keep left (Class 39), Probability: 0.0608
#   Sign: Ahead only (Class 35), Probability: 0.6659
# Top 5 softmax probabilities for Image 51:
#   Sign: Go straight or right (Class 36), Probability: 0.0330
#   Sign: Go straight or left (Class 37), Probability: 0.0347
#   Sign: Keep right (Class 38), Probability: 0.0383
#   Sign: Keep left (Class 39), Probability: 0.0598
#   Sign: Ahead only (Class 35), Probability: 0.6694
# Top 5 softmax probabilities for Image 52:
#   Sign: Go straight or right (Class 36), Probability: 0.0336
#   Sign: Go straight or left (Class 37), Probability: 0.0344
#   Sign: Keep right (Class 38), Probability: 0.0393
#   Sign: Keep left (Class 39), Probability: 0.0604
#   Sign: Ahead only (Class 35), Probability: 0.6702
# Top 5 softmax probabilities for Image 53:
#   Sign: Go straight or left (Class 37), Probability: 0.0344
#   Sign: Go straight or right (Class 36), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0374
#   Sign: Keep left (Class 39), Probability: 0.0602
#   Sign: Ahead only (Class 35), Probability: 0.6706
# Top 5 softmax probabilities for Image 54:
#   Sign: Go straight or right (Class 36), Probability: 0.0345
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0380
#   Sign: Keep left (Class 39), Probability: 0.0610
#   Sign: Ahead only (Class 35), Probability: 0.6651
# Top 5 softmax probabilities for Image 55:
#   Sign: Go straight or right (Class 36), Probability: 0.0332
#   Sign: Go straight or left (Class 37), Probability: 0.0340
#   Sign: Keep right (Class 38), Probability: 0.0384
#   Sign: Keep left (Class 39), Probability: 0.0600
#   Sign: Ahead only (Class 35), Probability: 0.6722
# Top 5 softmax probabilities for Image 56:
#   Sign: Go straight or right (Class 36), Probability: 0.0330
#   Sign: Go straight or left (Class 37), Probability: 0.0332
#   Sign: Keep right (Class 38), Probability: 0.0377
#   Sign: Keep left (Class 39), Probability: 0.0581
#   Sign: Ahead only (Class 35), Probability: 0.6831
# Top 5 softmax probabilities for Image 57:
#   Sign: Go straight or right (Class 36), Probability: 0.0335
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0391
#   Sign: Keep left (Class 39), Probability: 0.0603
#   Sign: Ahead only (Class 35), Probability: 0.6669
# Top 5 softmax probabilities for Image 58:
#   Sign: Go straight or right (Class 36), Probability: 0.0338
#   Sign: Go straight or left (Class 37), Probability: 0.0340
#   Sign: Keep right (Class 38), Probability: 0.0389
#   Sign: Keep left (Class 39), Probability: 0.0589
#   Sign: Ahead only (Class 35), Probability: 0.6687
# Top 5 softmax probabilities for Image 59:
#   Sign: Go straight or left (Class 37), Probability: 0.0349
#   Sign: Go straight or right (Class 36), Probability: 0.0380
#   Sign: Keep right (Class 38), Probability: 0.0413
#   Sign: Keep left (Class 39), Probability: 0.0605
#   Sign: Ahead only (Class 35), Probability: 0.6607
# Top 5 softmax probabilities for Image 60:
#   Sign: Go straight or right (Class 36), Probability: 0.0336
#   Sign: Go straight or left (Class 37), Probability: 0.0350
#   Sign: Keep right (Class 38), Probability: 0.0392
#   Sign: Keep left (Class 39), Probability: 0.0604
#   Sign: Ahead only (Class 35), Probability: 0.6649
# Top 5 softmax probabilities for Image 61:
#   Sign: Go straight or right (Class 36), Probability: 0.0320
#   Sign: Go straight or left (Class 37), Probability: 0.0341
#   Sign: Keep right (Class 38), Probability: 0.0375
#   Sign: Keep left (Class 39), Probability: 0.0591
#   Sign: Ahead only (Class 35), Probability: 0.6748
# Top 5 softmax probabilities for Image 62:
#   Sign: Go straight or right (Class 36), Probability: 0.0337
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0390
#   Sign: Keep left (Class 39), Probability: 0.0597
#   Sign: Ahead only (Class 35), Probability: 0.6680
# Top 5 softmax probabilities for Image 63:
#   Sign: Go straight or left (Class 37), Probability: 0.0342
#   Sign: Go straight or right (Class 36), Probability: 0.0362
#   Sign: Keep right (Class 38), Probability: 0.0407
#   Sign: Keep left (Class 39), Probability: 0.0624
#   Sign: Ahead only (Class 35), Probability: 0.6614
# Top 5 softmax probabilities for Image 64:
#   Sign: Go straight or right (Class 36), Probability: 0.0332
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0385
#   Sign: Keep left (Class 39), Probability: 0.0604
#   Sign: Ahead only (Class 35), Probability: 0.6682
# Top 5 softmax probabilities for Image 65:
#   Sign: Go straight or right (Class 36), Probability: 0.0327
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0385
#   Sign: Keep left (Class 39), Probability: 0.0603
#   Sign: Ahead only (Class 35), Probability: 0.6688
# Top 5 softmax probabilities for Image 66:
#   Sign: Go straight or left (Class 37), Probability: 0.0350
#   Sign: Go straight or right (Class 36), Probability: 0.0352
#   Sign: Keep right (Class 38), Probability: 0.0383
#   Sign: Keep left (Class 39), Probability: 0.0601
#   Sign: Ahead only (Class 35), Probability: 0.6625
# Top 5 softmax probabilities for Image 67:
#   Sign: Go straight or left (Class 37), Probability: 0.0334
#   Sign: Go straight or right (Class 36), Probability: 0.0338
#   Sign: Keep right (Class 38), Probability: 0.0374
#   Sign: Keep left (Class 39), Probability: 0.0592
#   Sign: Ahead only (Class 35), Probability: 0.6758
# Top 5 softmax probabilities for Image 68:
#   Sign: Go straight or right (Class 36), Probability: 0.0338
#   Sign: Go straight or left (Class 37), Probability: 0.0348
#   Sign: Keep right (Class 38), Probability: 0.0397
#   Sign: Keep left (Class 39), Probability: 0.0608
#   Sign: Ahead only (Class 35), Probability: 0.6653
# Top 5 softmax probabilities for Image 69:
#   Sign: Go straight or left (Class 37), Probability: 0.0348
#   Sign: Go straight or right (Class 36), Probability: 0.0351
#   Sign: Keep right (Class 38), Probability: 0.0398
#   Sign: Keep left (Class 39), Probability: 0.0622
#   Sign: Ahead only (Class 35), Probability: 0.6589
# Top 5 softmax probabilities for Image 70:
#   Sign: Go straight or right (Class 36), Probability: 0.0333
#   Sign: Go straight or left (Class 37), Probability: 0.0348
#   Sign: Keep right (Class 38), Probability: 0.0388
#   Sign: Keep left (Class 39), Probability: 0.0613
#   Sign: Ahead only (Class 35), Probability: 0.6653
# Top 5 softmax probabilities for Image 71:
#   Sign: Go straight or left (Class 37), Probability: 0.0341
#   Sign: Go straight or right (Class 36), Probability: 0.0354
#   Sign: Keep right (Class 38), Probability: 0.0394
#   Sign: Keep left (Class 39), Probability: 0.0580
#   Sign: Ahead only (Class 35), Probability: 0.6705
# Top 5 softmax probabilities for Image 72:
#   Sign: Go straight or right (Class 36), Probability: 0.0332
#   Sign: Go straight or left (Class 37), Probability: 0.0347
#   Sign: Keep right (Class 38), Probability: 0.0383
#   Sign: Keep left (Class 39), Probability: 0.0602
#   Sign: Ahead only (Class 35), Probability: 0.6690
# Top 5 softmax probabilities for Image 73:
#   Sign: Go straight or right (Class 36), Probability: 0.0331
#   Sign: Go straight or left (Class 37), Probability: 0.0348
#   Sign: Keep right (Class 38), Probability: 0.0383
#   Sign: Keep left (Class 39), Probability: 0.0602
#   Sign: Ahead only (Class 35), Probability: 0.6685
# Top 5 softmax probabilities for Image 74:
#   Sign: Go straight or right (Class 36), Probability: 0.0352
#   Sign: Go straight or left (Class 37), Probability: 0.0360
#   Sign: Keep right (Class 38), Probability: 0.0402
#   Sign: Keep left (Class 39), Probability: 0.0615
#   Sign: Ahead only (Class 35), Probability: 0.6589
# Top 5 softmax probabilities for Image 75:
#   Sign: Go straight or right (Class 36), Probability: 0.0335
#   Sign: Go straight or left (Class 37), Probability: 0.0348
#   Sign: Keep right (Class 38), Probability: 0.0394
#   Sign: Keep left (Class 39), Probability: 0.0607
#   Sign: Ahead only (Class 35), Probability: 0.6664
# Top 5 softmax probabilities for Image 76:
#   Sign: Go straight or right (Class 36), Probability: 0.0322
#   Sign: Go straight or left (Class 37), Probability: 0.0341
#   Sign: Keep right (Class 38), Probability: 0.0378
#   Sign: Keep left (Class 39), Probability: 0.0607
#   Sign: Ahead only (Class 35), Probability: 0.6753
# Top 5 softmax probabilities for Image 77:
#   Sign: Go straight or left (Class 37), Probability: 0.0340
#   Sign: Go straight or right (Class 36), Probability: 0.0344
#   Sign: Keep right (Class 38), Probability: 0.0383
#   Sign: Keep left (Class 39), Probability: 0.0621
#   Sign: Ahead only (Class 35), Probability: 0.6631
# Top 5 softmax probabilities for Image 78:
#   Sign: Go straight or right (Class 36), Probability: 0.0330
#   Sign: Go straight or left (Class 37), Probability: 0.0342
#   Sign: Keep right (Class 38), Probability: 0.0381
#   Sign: Keep left (Class 39), Probability: 0.0613
#   Sign: Ahead only (Class 35), Probability: 0.6728
# Top 5 softmax probabilities for Image 79:
#   Sign: Go straight or left (Class 37), Probability: 0.0344
#   Sign: Go straight or right (Class 36), Probability: 0.0358
#   Sign: Keep right (Class 38), Probability: 0.0408
#   Sign: Keep left (Class 39), Probability: 0.0612
#   Sign: Ahead only (Class 35), Probability: 0.6550
# Top 5 softmax probabilities for Image 80:
#   Sign: Go straight or left (Class 37), Probability: 0.0356
#   Sign: Go straight or right (Class 36), Probability: 0.0359
#   Sign: Keep right (Class 38), Probability: 0.0402
#   Sign: Keep left (Class 39), Probability: 0.0623
#   Sign: Ahead only (Class 35), Probability: 0.6556
# Top 5 softmax probabilities for Image 81:
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Go straight or right (Class 36), Probability: 0.0347
#   Sign: Keep right (Class 38), Probability: 0.0394
#   Sign: Keep left (Class 39), Probability: 0.0602
#   Sign: Ahead only (Class 35), Probability: 0.6643
# Top 5 softmax probabilities for Image 82:
#   Sign: Go straight or right (Class 36), Probability: 0.0312
#   Sign: Go straight or left (Class 37), Probability: 0.0342
#   Sign: Keep right (Class 38), Probability: 0.0367
#   Sign: Keep left (Class 39), Probability: 0.0620
#   Sign: Ahead only (Class 35), Probability: 0.6758
# Top 5 softmax probabilities for Image 83:
#   Sign: Go straight or right (Class 36), Probability: 0.0333
#   Sign: Go straight or left (Class 37), Probability: 0.0347
#   Sign: Keep right (Class 38), Probability: 0.0385
#   Sign: Keep left (Class 39), Probability: 0.0602
#   Sign: Ahead only (Class 35), Probability: 0.6683
# Top 5 softmax probabilities for Image 84:
#   Sign: Go straight or right (Class 36), Probability: 0.0327
#   Sign: Go straight or left (Class 37), Probability: 0.0337
#   Sign: Keep right (Class 38), Probability: 0.0374
#   Sign: Keep left (Class 39), Probability: 0.0602
#   Sign: Ahead only (Class 35), Probability: 0.6748
# Top 5 softmax probabilities for Image 85:
#   Sign: Go straight or right (Class 36), Probability: 0.0337
#   Sign: Go straight or left (Class 37), Probability: 0.0342
#   Sign: Keep right (Class 38), Probability: 0.0392
#   Sign: Keep left (Class 39), Probability: 0.0596
#   Sign: Ahead only (Class 35), Probability: 0.6692
# Top 5 softmax probabilities for Image 86:
#   Sign: Go straight or right (Class 36), Probability: 0.0316
#   Sign: Go straight or left (Class 37), Probability: 0.0344
#   Sign: Keep right (Class 38), Probability: 0.0374
#   Sign: Keep left (Class 39), Probability: 0.0605
#   Sign: Ahead only (Class 35), Probability: 0.6734
# Top 5 softmax probabilities for Image 87:
#   Sign: Go straight or right (Class 36), Probability: 0.0338
#   Sign: Go straight or left (Class 37), Probability: 0.0347
#   Sign: Keep right (Class 38), Probability: 0.0396
#   Sign: Keep left (Class 39), Probability: 0.0609
#   Sign: Ahead only (Class 35), Probability: 0.6658
# Top 5 softmax probabilities for Image 88:
#   Sign: Go straight or right (Class 36), Probability: 0.0342
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0399
#   Sign: Keep left (Class 39), Probability: 0.0610
#   Sign: Ahead only (Class 35), Probability: 0.6637
# Top 5 softmax probabilities for Image 89:
#   Sign: Go straight or right (Class 36), Probability: 0.0335
#   Sign: Go straight or left (Class 37), Probability: 0.0349
#   Sign: Keep right (Class 38), Probability: 0.0386
#   Sign: Keep left (Class 39), Probability: 0.0612
#   Sign: Ahead only (Class 35), Probability: 0.6657
# Top 5 softmax probabilities for Image 90:
#   Sign: Go straight or left (Class 37), Probability: 0.0356
#   Sign: Go straight or right (Class 36), Probability: 0.0361
#   Sign: Keep right (Class 38), Probability: 0.0431
#   Sign: Keep left (Class 39), Probability: 0.0608
#   Sign: Ahead only (Class 35), Probability: 0.6537
# Top 5 softmax probabilities for Image 91:
#   Sign: Go straight or right (Class 36), Probability: 0.0331
#   Sign: Go straight or left (Class 37), Probability: 0.0344
#   Sign: Keep right (Class 38), Probability: 0.0386
#   Sign: Keep left (Class 39), Probability: 0.0601
#   Sign: Ahead only (Class 35), Probability: 0.6692
# Top 5 softmax probabilities for Image 92:
#   Sign: Go straight or right (Class 36), Probability: 0.0354
#   Sign: Go straight or left (Class 37), Probability: 0.0357
#   Sign: Keep right (Class 38), Probability: 0.0407
#   Sign: Keep left (Class 39), Probability: 0.0623
#   Sign: Ahead only (Class 35), Probability: 0.6545
# Top 5 softmax probabilities for Image 93:
#   Sign: Go straight or right (Class 36), Probability: 0.0336
#   Sign: Go straight or left (Class 37), Probability: 0.0348
#   Sign: Keep right (Class 38), Probability: 0.0389
#   Sign: Keep left (Class 39), Probability: 0.0610
#   Sign: Ahead only (Class 35), Probability: 0.6673
# Top 5 softmax probabilities for Image 94:
#   Sign: Go straight or right (Class 36), Probability: 0.0329
#   Sign: Go straight or left (Class 37), Probability: 0.0342
#   Sign: Keep right (Class 38), Probability: 0.0377
#   Sign: Keep left (Class 39), Probability: 0.0609
#   Sign: Ahead only (Class 35), Probability: 0.6737
# Top 5 softmax probabilities for Image 95:
#   Sign: Go straight or right (Class 36), Probability: 0.0337
#   Sign: Go straight or left (Class 37), Probability: 0.0347
#   Sign: Keep right (Class 38), Probability: 0.0399
#   Sign: Keep left (Class 39), Probability: 0.0613
#   Sign: Ahead only (Class 35), Probability: 0.6643
# Top 5 softmax probabilities for Image 96:
#   Sign: Go straight or right (Class 36), Probability: 0.0343
#   Sign: Go straight or left (Class 37), Probability: 0.0352
#   Sign: Keep right (Class 38), Probability: 0.0403
#   Sign: Keep left (Class 39), Probability: 0.0617
#   Sign: Ahead only (Class 35), Probability: 0.6566
# Top 5 softmax probabilities for Image 97:
#   Sign: Go straight or right (Class 36), Probability: 0.0330
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0386
#   Sign: Keep left (Class 39), Probability: 0.0613
#   Sign: Ahead only (Class 35), Probability: 0.6679
# Top 5 softmax probabilities for Image 98:
#   Sign: Go straight or right (Class 36), Probability: 0.0331
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0386
#   Sign: Keep left (Class 39), Probability: 0.0607
#   Sign: Ahead only (Class 35), Probability: 0.6684
# Top 5 softmax probabilities for Image 99:
#   Sign: Go straight or right (Class 36), Probability: 0.0333
#   Sign: Go straight or left (Class 37), Probability: 0.0343
#   Sign: Keep right (Class 38), Probability: 0.0379
#   Sign: Keep left (Class 39), Probability: 0.0603
#   Sign: Ahead only (Class 35), Probability: 0.6702
# Top 5 softmax probabilities for Image 100:
#   Sign: Go straight or right (Class 36), Probability: 0.0318
#   Sign: Go straight or left (Class 37), Probability: 0.0342
#   Sign: Keep right (Class 38), Probability: 0.0378
#   Sign: Keep left (Class 39), Probability: 0.0612
#   Sign: Ahead only (Class 35), Probability: 0.6731
# Top 5 softmax probabilities for Image 101:
#   Sign: Go straight or right (Class 36), Probability: 0.0344
#   Sign: Go straight or left (Class 37), Probability: 0.0357
#   Sign: Keep right (Class 38), Probability: 0.0412
#   Sign: Keep left (Class 39), Probability: 0.0629
#   Sign: Ahead only (Class 35), Probability: 0.6553
# Top 5 softmax probabilities for Image 102:
#   Sign: Go straight or left (Class 37), Probability: 0.0348
#   Sign: Go straight or right (Class 36), Probability: 0.0351
#   Sign: Keep right (Class 38), Probability: 0.0394
#   Sign: Keep left (Class 39), Probability: 0.0599
#   Sign: Ahead only (Class 35), Probability: 0.6627
# Top 5 softmax probabilities for Image 103:
#   Sign: Go straight or right (Class 36), Probability: 0.0333
#   Sign: Go straight or left (Class 37), Probability: 0.0345
#   Sign: Keep right (Class 38), Probability: 0.0387
#   Sign: Keep left (Class 39), Probability: 0.0600
#   Sign: Ahead only (Class 35), Probability: 0.6688
# Top 5 softmax probabilities for Image 104:
#   Sign: Go straight or right (Class 36), Probability: 0.0342
#   Sign: Go straight or left (Class 37), Probability: 0.0347
#   Sign: Keep right (Class 38), Probability: 0.0396
#   Sign: Keep left (Class 39), Probability: 0.0607
#   Sign: Ahead only (Class 35), Probability: 0.6651
# Top 5 softmax probabilities for Image 105:
#   Sign: Go straight or left (Class 37), Probability: 0.0349
#   Sign: Go straight or right (Class 36), Probability: 0.0398
#   Sign: Keep right (Class 38), Probability: 0.0431
#   Sign: Keep left (Class 39), Probability: 0.0632
#   Sign: Ahead only (Class 35), Probability: 0.6452
# Top 5 softmax probabilities for Image 106:
#   Sign: Go straight or right (Class 36), Probability: 0.0346
#   Sign: Go straight or left (Class 37), Probability: 0.0360
#   Sign: Keep right (Class 38), Probability: 0.0409
#   Sign: Keep left (Class 39), Probability: 0.0642
#   Sign: Ahead only (Class 35), Probability: 0.6500
# Top 5 softmax probabilities for Image 107:
#   Sign: Go straight or right (Class 36), Probability: 0.0325
#   Sign: Go straight or left (Class 37), Probability: 0.0345
#   Sign: Keep right (Class 38), Probability: 0.0379
#   Sign: Keep left (Class 39), Probability: 0.0599
#   Sign: Ahead only (Class 35), Probability: 0.6710
# Top 5 softmax probabilities for Image 108:
#   Sign: Go straight or right (Class 36), Probability: 0.0331
#   Sign: Go straight or left (Class 37), Probability: 0.0352
#   Sign: Keep right (Class 38), Probability: 0.0385
#   Sign: Keep left (Class 39), Probability: 0.0616
#   Sign: Ahead only (Class 35), Probability: 0.6659
# Top 5 softmax probabilities for Image 109:
#   Sign: Go straight or left (Class 37), Probability: 0.0324
#   Sign: Go straight or right (Class 36), Probability: 0.0333
#   Sign: Keep right (Class 38), Probability: 0.0378
#   Sign: Keep left (Class 39), Probability: 0.0578
#   Sign: Ahead only (Class 35), Probability: 0.6863
# Top 5 softmax probabilities for Image 110:
#   Sign: Go straight or right (Class 36), Probability: 0.0332
#   Sign: Go straight or left (Class 37), Probability: 0.0345
#   Sign: Keep right (Class 38), Probability: 0.0387
#   Sign: Keep left (Class 39), Probability: 0.0601
#   Sign: Ahead only (Class 35), Probability: 0.6686
# Top 5 softmax probabilities for Image 111:
#   Sign: Go straight or left (Class 37), Probability: 0.0362
#   Sign: Go straight or right (Class 36), Probability: 0.0368
#   Sign: Keep right (Class 38), Probability: 0.0411
#   Sign: Keep left (Class 39), Probability: 0.0615
#   Sign: Ahead only (Class 35), Probability: 0.6477
# Top 5 softmax probabilities for Image 112:
#   Sign: Go straight or right (Class 36), Probability: 0.0345
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0391
#   Sign: Keep left (Class 39), Probability: 0.0604
#   Sign: Ahead only (Class 35), Probability: 0.6703
# Top 5 softmax probabilities for Image 113:
#   Sign: Go straight or right (Class 36), Probability: 0.0334
#   Sign: Go straight or left (Class 37), Probability: 0.0347
#   Sign: Keep right (Class 38), Probability: 0.0391
#   Sign: Keep left (Class 39), Probability: 0.0606
#   Sign: Ahead only (Class 35), Probability: 0.6657
# Top 5 softmax probabilities for Image 114:
#   Sign: Go straight or left (Class 37), Probability: 0.0351
#   Sign: Go straight or right (Class 36), Probability: 0.0354
#   Sign: Keep right (Class 38), Probability: 0.0391
#   Sign: Keep left (Class 39), Probability: 0.0603
#   Sign: Ahead only (Class 35), Probability: 0.6574
# Top 5 softmax probabilities for Image 115:
#   Sign: Go straight or right (Class 36), Probability: 0.0333
#   Sign: Go straight or left (Class 37), Probability: 0.0347
#   Sign: Keep right (Class 38), Probability: 0.0389
#   Sign: Keep left (Class 39), Probability: 0.0603
#   Sign: Ahead only (Class 35), Probability: 0.6663
# Top 5 softmax probabilities for Image 116:
#   Sign: Go straight or left (Class 37), Probability: 0.0347
#   Sign: Go straight or right (Class 36), Probability: 0.0354
#   Sign: Keep right (Class 38), Probability: 0.0381
#   Sign: Keep left (Class 39), Probability: 0.0603
#   Sign: Ahead only (Class 35), Probability: 0.6658
# Top 5 softmax probabilities for Image 117:
#   Sign: Go straight or left (Class 37), Probability: 0.0338
#   Sign: Go straight or right (Class 36), Probability: 0.0351
#   Sign: Keep right (Class 38), Probability: 0.0378
#   Sign: Keep left (Class 39), Probability: 0.0610
#   Sign: Ahead only (Class 35), Probability: 0.6706
# Top 5 softmax probabilities for Image 118:
#   Sign: Go straight or left (Class 37), Probability: 0.0350
#   Sign: Go straight or right (Class 36), Probability: 0.0355
#   Sign: Keep right (Class 38), Probability: 0.0420
#   Sign: Keep left (Class 39), Probability: 0.0597
#   Sign: Ahead only (Class 35), Probability: 0.6582
# Top 5 softmax probabilities for Image 119:
#   Sign: Go straight or right (Class 36), Probability: 0.0364
#   Sign: Go straight or left (Class 37), Probability: 0.0369
#   Sign: Keep right (Class 38), Probability: 0.0431
#   Sign: Keep left (Class 39), Probability: 0.0639
#   Sign: Ahead only (Class 35), Probability: 0.6416
# Top 5 softmax probabilities for Image 120:
#   Sign: Go straight or right (Class 36), Probability: 0.0341
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0408
#   Sign: Keep left (Class 39), Probability: 0.0596
#   Sign: Ahead only (Class 35), Probability: 0.6665
# Top 5 softmax probabilities for Image 121:
#   Sign: Go straight or right (Class 36), Probability: 0.0337
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0392
#   Sign: Keep left (Class 39), Probability: 0.0600
#   Sign: Ahead only (Class 35), Probability: 0.6670
# Top 5 softmax probabilities for Image 122:
#   Sign: Go straight or right (Class 36), Probability: 0.0336
#   Sign: Go straight or left (Class 37), Probability: 0.0347
#   Sign: Keep right (Class 38), Probability: 0.0394
#   Sign: Keep left (Class 39), Probability: 0.0612
#   Sign: Ahead only (Class 35), Probability: 0.6657
# Top 5 softmax probabilities for Image 123:
#   Sign: Go straight or left (Class 37), Probability: 0.0333
#   Sign: Go straight or right (Class 36), Probability: 0.0335
#   Sign: Keep right (Class 38), Probability: 0.0392
#   Sign: Keep left (Class 39), Probability: 0.0578
#   Sign: Ahead only (Class 35), Probability: 0.6734
# Top 5 softmax probabilities for Image 124:
#   Sign: Go straight or right (Class 36), Probability: 0.0316
#   Sign: Go straight or left (Class 37), Probability: 0.0343
#   Sign: Keep right (Class 38), Probability: 0.0377
#   Sign: Keep left (Class 39), Probability: 0.0613
#   Sign: Ahead only (Class 35), Probability: 0.6726
# Top 5 softmax probabilities for Image 125:
#   Sign: Go straight or right (Class 36), Probability: 0.0340
#   Sign: Go straight or left (Class 37), Probability: 0.0344
#   Sign: Keep right (Class 38), Probability: 0.0389
#   Sign: Keep left (Class 39), Probability: 0.0604
#   Sign: Ahead only (Class 35), Probability: 0.6671
# Top 5 softmax probabilities for Image 126:
#   Sign: Go straight or right (Class 36), Probability: 0.0334
#   Sign: Go straight or left (Class 37), Probability: 0.0349
#   Sign: Keep right (Class 38), Probability: 0.0396
#   Sign: Keep left (Class 39), Probability: 0.0605
#   Sign: Ahead only (Class 35), Probability: 0.6658
# Top 5 softmax probabilities for Image 127:
#   Sign: Go straight or right (Class 36), Probability: 0.0334
#   Sign: Go straight or left (Class 37), Probability: 0.0342
#   Sign: Keep right (Class 38), Probability: 0.0390
#   Sign: Keep left (Class 39), Probability: 0.0611
#   Sign: Ahead only (Class 35), Probability: 0.6693
# Top 5 softmax probabilities for Image 128:
#   Sign: Go straight or right (Class 36), Probability: 0.0332
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0384
#   Sign: Keep left (Class 39), Probability: 0.0602
#   Sign: Ahead only (Class 35), Probability: 0.6678
# Top 5 softmax probabilities for Image 129:
#   Sign: Go straight or right (Class 36), Probability: 0.0348
#   Sign: Go straight or left (Class 37), Probability: 0.0350
#   Sign: Keep right (Class 38), Probability: 0.0408
#   Sign: Keep left (Class 39), Probability: 0.0623
#   Sign: Ahead only (Class 35), Probability: 0.6645
# Top 5 softmax probabilities for Image 130:
#   Sign: Go straight or right (Class 36), Probability: 0.0332
#   Sign: Go straight or left (Class 37), Probability: 0.0345
#   Sign: Keep right (Class 38), Probability: 0.0387
#   Sign: Keep left (Class 39), Probability: 0.0603
#   Sign: Ahead only (Class 35), Probability: 0.6681
# Top 5 softmax probabilities for Image 131:
#   Sign: Go straight or left (Class 37), Probability: 0.0348
#   Sign: Go straight or right (Class 36), Probability: 0.0388
#   Sign: Keep right (Class 38), Probability: 0.0428
#   Sign: Keep left (Class 39), Probability: 0.0629
#   Sign: Ahead only (Class 35), Probability: 0.6485
# Top 5 softmax probabilities for Image 132:
#   Sign: Go straight or right (Class 36), Probability: 0.0339
#   Sign: Go straight or left (Class 37), Probability: 0.0347
#   Sign: Keep right (Class 38), Probability: 0.0408
#   Sign: Keep left (Class 39), Probability: 0.0621
#   Sign: Ahead only (Class 35), Probability: 0.6626
# Top 5 softmax probabilities for Image 133:
#   Sign: Go straight or right (Class 36), Probability: 0.0340
#   Sign: Go straight or left (Class 37), Probability: 0.0368
#   Sign: Keep right (Class 38), Probability: 0.0404
#   Sign: Keep left (Class 39), Probability: 0.0652
#   Sign: Ahead only (Class 35), Probability: 0.6505
# Top 5 softmax probabilities for Image 134:
#   Sign: Go straight or left (Class 37), Probability: 0.0341
#   Sign: Go straight or right (Class 36), Probability: 0.0356
#   Sign: Keep right (Class 38), Probability: 0.0397
#   Sign: Keep left (Class 39), Probability: 0.0589
#   Sign: Ahead only (Class 35), Probability: 0.6683
# Top 5 softmax probabilities for Image 135:
#   Sign: Go straight or left (Class 37), Probability: 0.0353
#   Sign: Go straight or right (Class 36), Probability: 0.0356
#   Sign: Keep right (Class 38), Probability: 0.0411
#   Sign: Keep left (Class 39), Probability: 0.0603
#   Sign: Ahead only (Class 35), Probability: 0.6588
# Top 5 softmax probabilities for Image 136:
#   Sign: Go straight or right (Class 36), Probability: 0.0339
#   Sign: Go straight or left (Class 37), Probability: 0.0347
#   Sign: Keep right (Class 38), Probability: 0.0401
#   Sign: Keep left (Class 39), Probability: 0.0603
#   Sign: Ahead only (Class 35), Probability: 0.6633
# Top 5 softmax probabilities for Image 137:
#   Sign: Go straight or left (Class 37), Probability: 0.0343
#   Sign: Go straight or right (Class 36), Probability: 0.0366
#   Sign: Keep right (Class 38), Probability: 0.0408
#   Sign: Keep left (Class 39), Probability: 0.0598
#   Sign: Ahead only (Class 35), Probability: 0.6668
# Top 5 softmax probabilities for Image 138:
#   Sign: Go straight or right (Class 36), Probability: 0.0316
#   Sign: Go straight or left (Class 37), Probability: 0.0339
#   Sign: Keep right (Class 38), Probability: 0.0369
#   Sign: Keep left (Class 39), Probability: 0.0605
#   Sign: Ahead only (Class 35), Probability: 0.6793
# Top 5 softmax probabilities for Image 139:
#   Sign: Go straight or right (Class 36), Probability: 0.0331
#   Sign: Go straight or left (Class 37), Probability: 0.0350
#   Sign: Keep right (Class 38), Probability: 0.0393
#   Sign: Keep left (Class 39), Probability: 0.0612
#   Sign: Ahead only (Class 35), Probability: 0.6672
# Top 5 softmax probabilities for Image 140:
#   Sign: Go straight or left (Class 37), Probability: 0.0352
#   Sign: Go straight or right (Class 36), Probability: 0.0373
#   Sign: Keep right (Class 38), Probability: 0.0409
#   Sign: Keep left (Class 39), Probability: 0.0621
#   Sign: Ahead only (Class 35), Probability: 0.6525
# Top 5 softmax probabilities for Image 141:
#   Sign: Go straight or right (Class 36), Probability: 0.0343
#   Sign: Go straight or left (Class 37), Probability: 0.0348
#   Sign: Keep right (Class 38), Probability: 0.0399
#   Sign: Keep left (Class 39), Probability: 0.0605
#   Sign: Ahead only (Class 35), Probability: 0.6648
# Top 5 softmax probabilities for Image 142:
#   Sign: Go straight or right (Class 36), Probability: 0.0333
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0397
#   Sign: Keep left (Class 39), Probability: 0.0611
#   Sign: Ahead only (Class 35), Probability: 0.6642
# Top 5 softmax probabilities for Image 143:
#   Sign: Go straight or right (Class 36), Probability: 0.0347
#   Sign: Go straight or left (Class 37), Probability: 0.0351
#   Sign: Keep right (Class 38), Probability: 0.0384
#   Sign: Keep left (Class 39), Probability: 0.0623
#   Sign: Ahead only (Class 35), Probability: 0.6606
# Top 5 softmax probabilities for Image 144:
#   Sign: Go straight or right (Class 36), Probability: 0.0333
#   Sign: Go straight or left (Class 37), Probability: 0.0347
#   Sign: Keep right (Class 38), Probability: 0.0386
#   Sign: Keep left (Class 39), Probability: 0.0604
#   Sign: Ahead only (Class 35), Probability: 0.6679
# Top 5 softmax probabilities for Image 145:
#   Sign: Go straight or right (Class 36), Probability: 0.0363
#   Sign: Go straight or left (Class 37), Probability: 0.0379
#   Sign: Keep right (Class 38), Probability: 0.0413
#   Sign: Keep left (Class 39), Probability: 0.0597
#   Sign: Ahead only (Class 35), Probability: 0.6495
# Top 5 softmax probabilities for Image 146:
#   Sign: Go straight or right (Class 36), Probability: 0.0332
#   Sign: Go straight or left (Class 37), Probability: 0.0347
#   Sign: Keep right (Class 38), Probability: 0.0383
#   Sign: Keep left (Class 39), Probability: 0.0599
#   Sign: Ahead only (Class 35), Probability: 0.6682
# Top 5 softmax probabilities for Image 147:
#   Sign: Go straight or left (Class 37), Probability: 0.0339
#   Sign: Go straight or right (Class 36), Probability: 0.0357
#   Sign: Keep right (Class 38), Probability: 0.0407
#   Sign: Keep left (Class 39), Probability: 0.0603
#   Sign: Ahead only (Class 35), Probability: 0.6647
# Top 5 softmax probabilities for Image 148:
#   Sign: Go straight or right (Class 36), Probability: 0.0342
#   Sign: Go straight or left (Class 37), Probability: 0.0345
#   Sign: Keep right (Class 38), Probability: 0.0387
#   Sign: Keep left (Class 39), Probability: 0.0604
#   Sign: Ahead only (Class 35), Probability: 0.6660
# Top 5 softmax probabilities for Image 149:
#   Sign: Go straight or left (Class 37), Probability: 0.0347
#   Sign: Go straight or right (Class 36), Probability: 0.0354
#   Sign: Keep right (Class 38), Probability: 0.0412
#   Sign: Keep left (Class 39), Probability: 0.0587
#   Sign: Ahead only (Class 35), Probability: 0.6593
# Top 5 softmax probabilities for Image 150:
#   Sign: Go straight or left (Class 37), Probability: 0.0340
#   Sign: Go straight or right (Class 36), Probability: 0.0342
#   Sign: Keep right (Class 38), Probability: 0.0387
#   Sign: Keep left (Class 39), Probability: 0.0581
#   Sign: Ahead only (Class 35), Probability: 0.6697
# Top 5 softmax probabilities for Image 151:
#   Sign: Go straight or right (Class 36), Probability: 0.0325
#   Sign: Go straight or left (Class 37), Probability: 0.0341
#   Sign: Keep right (Class 38), Probability: 0.0381
#   Sign: Keep left (Class 39), Probability: 0.0605
#   Sign: Ahead only (Class 35), Probability: 0.6711
# Top 5 softmax probabilities for Image 152:
#   Sign: Go straight or right (Class 36), Probability: 0.0327
#   Sign: Go straight or left (Class 37), Probability: 0.0345
#   Sign: Keep right (Class 38), Probability: 0.0380
#   Sign: Keep left (Class 39), Probability: 0.0603
#   Sign: Ahead only (Class 35), Probability: 0.6704
# ...
#   Sign: Go straight or left (Class 37), Probability: 0.0354
#   Sign: Keep right (Class 38), Probability: 0.0403
#   Sign: Keep left (Class 39), Probability: 0.0612
#   Sign: Ahead only (Class 35), Probability: 0.6605
# Top 5 softmax probabilities for Image 5924:
#   Sign: Go straight or right (Class 36), Probability: 0.0334
#   Sign: Go straight or left (Class 37), Probability: 0.0349
#   Sign: Keep right (Class 38), Probability: 0.0388
#   Sign: Keep left (Class 39), Probability: 0.0604
#   Sign: Ahead only (Class 35), Probability: 0.6640
# Top 5 softmax probabilities for Image 5925:
#   Sign: Go straight or right (Class 36), Probability: 0.0328
#   Sign: Go straight or left (Class 37), Probability: 0.0345
#   Sign: Keep right (Class 38), Probability: 0.0384
#   Sign: Keep left (Class 39), Probability: 0.0601
#   Sign: Ahead only (Class 35), Probability: 0.6691
# Top 5 softmax probabilities for Image 5926:
#   Sign: Go straight or right (Class 36), Probability: 0.0332
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0387
#   Sign: Keep left (Class 39), Probability: 0.0602
#   Sign: Ahead only (Class 35), Probability: 0.6675
# Top 5 softmax probabilities for Image 5927:
#   Sign: Go straight or right (Class 36), Probability: 0.0335
#   Sign: Go straight or left (Class 37), Probability: 0.0349
#   Sign: Keep right (Class 38), Probability: 0.0393
#   Sign: Keep left (Class 39), Probability: 0.0614
#   Sign: Ahead only (Class 35), Probability: 0.6640
# Top 5 softmax probabilities for Image 5928:
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Go straight or right (Class 36), Probability: 0.0354
#   Sign: Keep right (Class 38), Probability: 0.0410
#   Sign: Keep left (Class 39), Probability: 0.0588
#   Sign: Ahead only (Class 35), Probability: 0.6690
# Top 5 softmax probabilities for Image 5929:
#   Sign: Go straight or right (Class 36), Probability: 0.0337
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0397
#   Sign: Keep left (Class 39), Probability: 0.0604
#   Sign: Ahead only (Class 35), Probability: 0.6652
# Top 5 softmax probabilities for Image 5930:
#   Sign: Go straight or right (Class 36), Probability: 0.0331
#   Sign: Go straight or left (Class 37), Probability: 0.0345
#   Sign: Keep right (Class 38), Probability: 0.0385
#   Sign: Keep left (Class 39), Probability: 0.0600
#   Sign: Ahead only (Class 35), Probability: 0.6694
# Top 5 softmax probabilities for Image 5931:
#   Sign: Go straight or right (Class 36), Probability: 0.0326
#   Sign: Go straight or left (Class 37), Probability: 0.0348
#   Sign: Keep right (Class 38), Probability: 0.0380
#   Sign: Keep left (Class 39), Probability: 0.0606
#   Sign: Ahead only (Class 35), Probability: 0.6688
# Top 5 softmax probabilities for Image 5932:
#   Sign: Go straight or right (Class 36), Probability: 0.0324
#   Sign: Go straight or left (Class 37), Probability: 0.0349
#   Sign: Keep right (Class 38), Probability: 0.0384
#   Sign: Keep left (Class 39), Probability: 0.0605
#   Sign: Ahead only (Class 35), Probability: 0.6688
# Top 5 softmax probabilities for Image 5933:
#   Sign: Go straight or right (Class 36), Probability: 0.0336
#   Sign: Go straight or left (Class 37), Probability: 0.0350
#   Sign: Keep right (Class 38), Probability: 0.0386
#   Sign: Keep left (Class 39), Probability: 0.0610
#   Sign: Ahead only (Class 35), Probability: 0.6676
# Top 5 softmax probabilities for Image 5934:
#   Sign: Go straight or left (Class 37), Probability: 0.0345
#   Sign: Go straight or right (Class 36), Probability: 0.0351
#   Sign: Keep right (Class 38), Probability: 0.0399
#   Sign: Keep left (Class 39), Probability: 0.0598
#   Sign: Ahead only (Class 35), Probability: 0.6629
# Top 5 softmax probabilities for Image 5935:
#   Sign: Go straight or right (Class 36), Probability: 0.0326
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0382
#   Sign: Keep left (Class 39), Probability: 0.0600
#   Sign: Ahead only (Class 35), Probability: 0.6718
# Top 5 softmax probabilities for Image 5936:
#   Sign: Go straight or left (Class 37), Probability: 0.0336
#   Sign: Go straight or right (Class 36), Probability: 0.0355
#   Sign: Keep right (Class 38), Probability: 0.0375
#   Sign: Keep left (Class 39), Probability: 0.0563
#   Sign: Ahead only (Class 35), Probability: 0.6755
# Top 5 softmax probabilities for Image 5937:
#   Sign: Go straight or right (Class 36), Probability: 0.0332
#   Sign: Go straight or left (Class 37), Probability: 0.0344
#   Sign: Keep right (Class 38), Probability: 0.0379
#   Sign: Keep left (Class 39), Probability: 0.0597
#   Sign: Ahead only (Class 35), Probability: 0.6723
# Top 5 softmax probabilities for Image 5938:
#   Sign: Go straight or right (Class 36), Probability: 0.0346
#   Sign: Go straight or left (Class 37), Probability: 0.0350
#   Sign: Keep right (Class 38), Probability: 0.0383
#   Sign: Keep left (Class 39), Probability: 0.0636
#   Sign: Ahead only (Class 35), Probability: 0.6531
# Top 5 softmax probabilities for Image 5939:
#   Sign: Go straight or right (Class 36), Probability: 0.0332
#   Sign: Go straight or left (Class 37), Probability: 0.0351
#   Sign: Keep right (Class 38), Probability: 0.0390
#   Sign: Keep left (Class 39), Probability: 0.0607
#   Sign: Ahead only (Class 35), Probability: 0.6679
# Top 5 softmax probabilities for Image 5940:
#   Sign: Go straight or right (Class 36), Probability: 0.0327
#   Sign: Go straight or left (Class 37), Probability: 0.0345
#   Sign: Keep right (Class 38), Probability: 0.0382
#   Sign: Keep left (Class 39), Probability: 0.0598
#   Sign: Ahead only (Class 35), Probability: 0.6706
# Top 5 softmax probabilities for Image 5941:
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Go straight or right (Class 36), Probability: 0.0355
#   Sign: Keep right (Class 38), Probability: 0.0422
#   Sign: Keep left (Class 39), Probability: 0.0602
#   Sign: Ahead only (Class 35), Probability: 0.6594
# Top 5 softmax probabilities for Image 5942:
#   Sign: Go straight or right (Class 36), Probability: 0.0335
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0390
#   Sign: Keep left (Class 39), Probability: 0.0593
#   Sign: Ahead only (Class 35), Probability: 0.6684
# Top 5 softmax probabilities for Image 5943:
#   Sign: Go straight or right (Class 36), Probability: 0.0337
#   Sign: Go straight or left (Class 37), Probability: 0.0347
#   Sign: Keep right (Class 38), Probability: 0.0398
#   Sign: Keep left (Class 39), Probability: 0.0614
#   Sign: Ahead only (Class 35), Probability: 0.6650
# Top 5 softmax probabilities for Image 5944:
#   Sign: Go straight or left (Class 37), Probability: 0.0355
#   Sign: Go straight or right (Class 36), Probability: 0.0365
#   Sign: Keep right (Class 38), Probability: 0.0411
#   Sign: Keep left (Class 39), Probability: 0.0626
#   Sign: Ahead only (Class 35), Probability: 0.6533
# Top 5 softmax probabilities for Image 5945:
#   Sign: Go straight or right (Class 36), Probability: 0.0360
#   Sign: Go straight or left (Class 37), Probability: 0.0361
#   Sign: Keep right (Class 38), Probability: 0.0424
#   Sign: Keep left (Class 39), Probability: 0.0619
#   Sign: Ahead only (Class 35), Probability: 0.6538
# Top 5 softmax probabilities for Image 5946:
#   Sign: Go straight or right (Class 36), Probability: 0.0332
#   Sign: Go straight or left (Class 37), Probability: 0.0345
#   Sign: Keep right (Class 38), Probability: 0.0392
#   Sign: Keep left (Class 39), Probability: 0.0598
#   Sign: Ahead only (Class 35), Probability: 0.6678
# Top 5 softmax probabilities for Image 5947:
#   Sign: Go straight or right (Class 36), Probability: 0.0335
#   Sign: Go straight or left (Class 37), Probability: 0.0345
#   Sign: Keep right (Class 38), Probability: 0.0394
#   Sign: Keep left (Class 39), Probability: 0.0619
#   Sign: Ahead only (Class 35), Probability: 0.6646
# Top 5 softmax probabilities for Image 5948:
#   Sign: Go straight or right (Class 36), Probability: 0.0317
#   Sign: Go straight or left (Class 37), Probability: 0.0344
#   Sign: Keep right (Class 38), Probability: 0.0376
#   Sign: Keep left (Class 39), Probability: 0.0599
#   Sign: Ahead only (Class 35), Probability: 0.6789
# Top 5 softmax probabilities for Image 5949:
#   Sign: Go straight or right (Class 36), Probability: 0.0332
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0386
#   Sign: Keep left (Class 39), Probability: 0.0604
#   Sign: Ahead only (Class 35), Probability: 0.6682
# Top 5 softmax probabilities for Image 5950:
#   Sign: Go straight or left (Class 37), Probability: 0.0338
#   Sign: Go straight or right (Class 36), Probability: 0.0362
#   Sign: Keep right (Class 38), Probability: 0.0401
#   Sign: Keep left (Class 39), Probability: 0.0590
#   Sign: Ahead only (Class 35), Probability: 0.6672
# Top 5 softmax probabilities for Image 5951:
#   Sign: Go straight or right (Class 36), Probability: 0.0343
#   Sign: Go straight or left (Class 37), Probability: 0.0347
#   Sign: Keep right (Class 38), Probability: 0.0399
#   Sign: Keep left (Class 39), Probability: 0.0604
#   Sign: Ahead only (Class 35), Probability: 0.6640
# Top 5 softmax probabilities for Image 5952:
#   Sign: Go straight or right (Class 36), Probability: 0.0331
#   Sign: Go straight or left (Class 37), Probability: 0.0342
#   Sign: Keep right (Class 38), Probability: 0.0372
#   Sign: Keep left (Class 39), Probability: 0.0606
#   Sign: Ahead only (Class 35), Probability: 0.6725
# Top 5 softmax probabilities for Image 5953:
#   Sign: Go straight or right (Class 36), Probability: 0.0331
#   Sign: Go straight or left (Class 37), Probability: 0.0344
#   Sign: Keep right (Class 38), Probability: 0.0386
#   Sign: Keep left (Class 39), Probability: 0.0597
#   Sign: Ahead only (Class 35), Probability: 0.6693
# Top 5 softmax probabilities for Image 5954:
#   Sign: Go straight or right (Class 36), Probability: 0.0324
#   Sign: Go straight or left (Class 37), Probability: 0.0347
#   Sign: Keep right (Class 38), Probability: 0.0379
#   Sign: Keep left (Class 39), Probability: 0.0603
#   Sign: Ahead only (Class 35), Probability: 0.6705
# Top 5 softmax probabilities for Image 5955:
#   Sign: Go straight or right (Class 36), Probability: 0.0327
#   Sign: Go straight or left (Class 37), Probability: 0.0339
#   Sign: Keep right (Class 38), Probability: 0.0382
#   Sign: Keep left (Class 39), Probability: 0.0605
#   Sign: Ahead only (Class 35), Probability: 0.6700
# Top 5 softmax probabilities for Image 5956:
#   Sign: Go straight or right (Class 36), Probability: 0.0337
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0397
#   Sign: Keep left (Class 39), Probability: 0.0608
#   Sign: Ahead only (Class 35), Probability: 0.6656
# Top 5 softmax probabilities for Image 5957:
#   Sign: Go straight or right (Class 36), Probability: 0.0339
#   Sign: Go straight or left (Class 37), Probability: 0.0354
#   Sign: Keep right (Class 38), Probability: 0.0409
#   Sign: Keep left (Class 39), Probability: 0.0634
#   Sign: Ahead only (Class 35), Probability: 0.6610
# Top 5 softmax probabilities for Image 5958:
#   Sign: Go straight or right (Class 36), Probability: 0.0332
#   Sign: Go straight or left (Class 37), Probability: 0.0348
#   Sign: Keep right (Class 38), Probability: 0.0388
#   Sign: Keep left (Class 39), Probability: 0.0607
#   Sign: Ahead only (Class 35), Probability: 0.6681
# Top 5 softmax probabilities for Image 5959:
#   Sign: Go straight or left (Class 37), Probability: 0.0356
#   Sign: Go straight or right (Class 36), Probability: 0.0358
#   Sign: Keep right (Class 38), Probability: 0.0383
#   Sign: Keep left (Class 39), Probability: 0.0605
#   Sign: Ahead only (Class 35), Probability: 0.6586
# Top 5 softmax probabilities for Image 5960:
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Go straight or right (Class 36), Probability: 0.0350
#   Sign: Keep right (Class 38), Probability: 0.0398
#   Sign: Keep left (Class 39), Probability: 0.0609
#   Sign: Ahead only (Class 35), Probability: 0.6602
# Top 5 softmax probabilities for Image 5961:
#   Sign: Go straight or left (Class 37), Probability: 0.0336
#   Sign: Go straight or right (Class 36), Probability: 0.0344
#   Sign: Keep right (Class 38), Probability: 0.0382
#   Sign: Keep left (Class 39), Probability: 0.0590
#   Sign: Ahead only (Class 35), Probability: 0.6689
# Top 5 softmax probabilities for Image 5962:
#   Sign: Go straight or right (Class 36), Probability: 0.0327
#   Sign: Go straight or left (Class 37), Probability: 0.0345
#   Sign: Keep right (Class 38), Probability: 0.0388
#   Sign: Keep left (Class 39), Probability: 0.0608
#   Sign: Ahead only (Class 35), Probability: 0.6697
# Top 5 softmax probabilities for Image 5963:
#   Sign: Go straight or left (Class 37), Probability: 0.0339
#   Sign: Go straight or right (Class 36), Probability: 0.0349
#   Sign: Keep right (Class 38), Probability: 0.0395
#   Sign: Keep left (Class 39), Probability: 0.0598
#   Sign: Ahead only (Class 35), Probability: 0.6610
# Top 5 softmax probabilities for Image 5964:
#   Sign: Go straight or left (Class 37), Probability: 0.0347
#   Sign: Go straight or right (Class 36), Probability: 0.0347
#   Sign: Keep right (Class 38), Probability: 0.0400
#   Sign: Keep left (Class 39), Probability: 0.0593
#   Sign: Ahead only (Class 35), Probability: 0.6665
# Top 5 softmax probabilities for Image 5965:
#   Sign: Go straight or right (Class 36), Probability: 0.0320
#   Sign: Go straight or left (Class 37), Probability: 0.0341
#   Sign: Keep right (Class 38), Probability: 0.0384
#   Sign: Keep left (Class 39), Probability: 0.0601
#   Sign: Ahead only (Class 35), Probability: 0.6758
# Top 5 softmax probabilities for Image 5966:
#   Sign: Go straight or right (Class 36), Probability: 0.0337
#   Sign: Go straight or left (Class 37), Probability: 0.0344
#   Sign: Keep right (Class 38), Probability: 0.0389
#   Sign: Keep left (Class 39), Probability: 0.0608
#   Sign: Ahead only (Class 35), Probability: 0.6685
# Top 5 softmax probabilities for Image 5967:
#   Sign: Go straight or right (Class 36), Probability: 0.0342
#   Sign: Go straight or left (Class 37), Probability: 0.0351
#   Sign: Keep right (Class 38), Probability: 0.0399
#   Sign: Keep left (Class 39), Probability: 0.0608
#   Sign: Ahead only (Class 35), Probability: 0.6636
# Top 5 softmax probabilities for Image 5968:
#   Sign: Go straight or right (Class 36), Probability: 0.0332
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0385
#   Sign: Keep left (Class 39), Probability: 0.0605
#   Sign: Ahead only (Class 35), Probability: 0.6678
# Top 5 softmax probabilities for Image 5969:
#   Sign: Go straight or right (Class 36), Probability: 0.0324
#   Sign: Go straight or left (Class 37), Probability: 0.0343
#   Sign: Keep right (Class 38), Probability: 0.0381
#   Sign: Keep left (Class 39), Probability: 0.0610
#   Sign: Ahead only (Class 35), Probability: 0.6703
# Top 5 softmax probabilities for Image 5970:
#   Sign: Go straight or right (Class 36), Probability: 0.0339
#   Sign: Go straight or left (Class 37), Probability: 0.0353
#   Sign: Keep right (Class 38), Probability: 0.0392
#   Sign: Keep left (Class 39), Probability: 0.0616
#   Sign: Ahead only (Class 35), Probability: 0.6627
# Top 5 softmax probabilities for Image 5971:
#   Sign: Go straight or right (Class 36), Probability: 0.0336
#   Sign: Go straight or left (Class 37), Probability: 0.0346
#   Sign: Keep right (Class 38), Probability: 0.0390
#   Sign: Keep left (Class 39), Probability: 0.0592
#   Sign: Ahead only (Class 35), Probability: 0.6682
# Top 5 softmax probabilities for Image 5972:
#   Sign: Go straight or left (Class 37), Probability: 0.0344
#   Sign: Go straight or right (Class 36), Probability: 0.0349
#   Sign: Keep right (Class 38), Probability: 0.0390
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ### Project Writeup
#
# Once you have completed the code implementation, document your results in a project writeup using this [template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) as a guide. The writeup can be in a markdown or pdf file.

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.

# %% [markdown]
# ---
#
# ## Step 4 (Optional): Visualize the Neural Network's State with Test Images
#
#  This Section is not required to complete but acts as an additional excersise for understaning the output of a neural network's weights. While neural networks can be a great learning device they are often referred to as a black box. We can understand what the weights of a neural network look like better by plotting their feature maps. After successfully training your neural network you can see what it's feature maps look like by plotting the output of the network's weight layers in response to a test stimuli image. From these plotted feature maps, it's possible to see what characteristics of an image the network finds interesting. For a sign, maybe the inner network feature maps react with high activation to the sign's boundary outline or to the contrast in the sign's painted symbol.
#
#  Provided for you below is the function code that allows you to get the visualization output of any tensorflow weight layer you want. The inputs to the function should be a stimuli image, one used during training or a new one you provided, and then the tensorflow variable name that represents the layer's state during the training process, for instance if you wanted to see what the [LeNet lab's](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) feature maps looked like for it's second convolutional layer you could enter conv2 as the tf_activation variable.
#
# For an example of what feature map outputs look like, check out NVIDIA's results in their paper [End-to-End Deep Learning for Self-Driving Cars](https://devblogs.nvidia.com/parallelforall/deep-learning-self-driving-cars/) in the section Visualization of internal CNN State. NVIDIA was able to show that their network's inner weights had high activations to road boundary lines by comparing feature maps from an image with a clear path to one without. Try experimenting with a similar test to show that your trained network's weights are looking for interesting features, whether it's looking at differences in feature maps from images with or without a sign, or even what feature maps look like in a trained network vs a completely untrained one on the same sign image.
#
# <figure>
#  <img src="visualize_cnn.png" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above)</p>
#  </figcaption>
# </figure>
#  <p></p>

# %%
### Visualize your network's feature maps here.
### Feel free to use as many code cells as needed.

# image_input: the test image being fed into the network to produce the feature maps
# tf_activation: should be a tf variable name used during your training procedure that represents the calculated state of a specific weight layer
# activation_min/max: can be used to view the activation contrast in more detail, by default matplot sets min and max to the actual min and max values of the output
# plt_num: used to plot out multiple different weight feature map sets on the same block, just extend the plt number for each new feature map entry
# n_featuremaps: number of feature maps to plot, -1 to plot all.

def outputFeatureMap(image_input, tf_activation, activation_min=-1, activation_max=-1 ,plt_num=1, n_featuremaps=-1):
    # Here make sure to preprocess your image_input in a way your network expects
    # with size, normalization, ect if needed
    # image_input =
    # Note: x should be the same name as your network's tensorflow data placeholder variable
    # If you get an error tf_activation is not defined it may be having trouble accessing the variable from inside a function
    activation = tf_activation.eval(session=sess,feed_dict={x : image_input})
    if n_featuremaps == -1:
        featuremaps = activation.shape[3]
    else:
        featuremaps = min(n_featuremaps, activation.shape[3])
    num_rows = np.ceil(np.sqrt(featuremaps))
    num_cols = num_rows
    plt.figure(plt_num, figsize=(15,15))
    for featuremap in range(featuremaps):
        plt.subplot(num_rows, num_cols, featuremap+1) # sets the number of feature maps to show on each row and column
        plt.title('FeatureMap ' + str(featuremap)) # displays the feature map number
        if activation_min != -1 & activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin =activation_min, vmax=activation_max, cmap="gray")
        elif activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmax=activation_max, cmap="gray")
        elif activation_min !=-1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin=activation_min, cmap="gray")
        else:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", cmap="gray")
